# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
protocol = pd.read_csv("../output/protocols/protocol.csv")
protocol_queue = protocol[protocol.Event == "Queue"]
protocol_queue.head()
# Out:
#    Event  Time Marking
# 0  Queue  1.34       1
# 2  Queue  2.67       1
# 4  Queue  4.40       1
# 6  Queue  6.66       1
# 8  Queue  7.09       1

# %%
plt.rcParams.update({'font.size': 16})
plt.figure(figsize=(10,4))
plt.step(protocol_queue.Time,protocol_queue.Marking)
plt.ylabel("Queue size")
plt.xlabel("Simulation time")
plt.savefig("single_server_example_plot.pdf")
